# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('df1_pandas_viz.csv',index_col=0)
df2 = pd.read_csv('df2_pandas_viz.csv')
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['B'].plot(kind='hist')


#area, barh, bar, density, line, scatter, box, hexbin, pie
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.plot(kind='area')
# Out:
# <Axes: >

# %%
df2.plot(kind='bar', stacked = True)
# Out:
# <Axes: >

# %%
df1.plot(kind='scatter', x='C', y='B',c = 'D',s = df1['A']*90)
# Out:
# /Users/shrey/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='C', ylabel='B'>

# %%
df2.plot(kind='box')
# Out:
# <Axes: >

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>
